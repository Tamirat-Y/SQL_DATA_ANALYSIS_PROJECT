# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import squarify 
import calendar
import datetime 
from datetime import datetime 
# %matplotlib inline

# %%
import pandas as pd
top= pd.read_csv('top_paying_jobs.csv')

# %%
top.columns
# Out:
# Index(['Job_Title', 'Average_yearly_Salary'], dtype='object')

# %%
mpl.rcParams['font.size'] = 25
plt.figure(figsize=(14,12))
#mpl.rcParams['figure.figsize'] = (40, 12)

mpl.rcParams['figure.facecolor'] = '#00000000'

plt.barh(top.Job_Title,top.Average_yearly_Salary)


plt.title("Top 10 High_Paying Data Analyst Jobs", loc='center')    #'left','right'
plt.xlabel('Average_yearly_Salary')
plt.ylabel('Job_Title')
plt.grid(c='g',ls='--',lw=2.5) #alpha:  adjust the transparency
#plt.xticks(rotation=45);

# %%
import pandas as pd
demanding= pd.read_csv('demanding_skill_top_jobs.csv')

# %%
demanding
# Out:
#       skills  Skill_Count
# 0        sql            8
# 1     python            7
# 2    tableau            6
# 3          r            4
# 4  snowflake            3
# 5     pandas            3
# 6      excel            3
# 7  atlassian            2
# 8      azure            2
# 9       jira            2

# %%
mpl.rcParams['font.size'] = 25
plt.figure(figsize=(14,12))
#mpl.rcParams['figure.figsize'] = (40, 12)

mpl.rcParams['figure.facecolor'] = '#00000000'

plt.barh(demanding.skills,demanding.Skill_Count)


plt.title("Top 10 High Demanding Skills for High_Paying Data Analyst Jobs", loc='center')    #'left','right'
plt.xlabel('Skill_Count')
plt.ylabel('Skills')
plt.grid(c='g',ls='--',lw=.8) #alpha:  adjust the transparency
#plt.xticks(rotation=45);
