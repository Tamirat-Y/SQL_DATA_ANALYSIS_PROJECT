# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import squarify 
import calendar
import datetime 
from datetime import datetime 
# %matplotlib inline

# %%
import pandas as pd
top= pd.read_csv('top_paying_jobs.csv')

# %%
top.columns
# Out:
# Index(['Job_Title', 'Average_yearly_Salary'], dtype='object')

# %%
# before the plot



mpl.rcParams['font.size'] = 25
plt.figure(figsize=(14,12))
#mpl.rcParams['figure.figsize'] = (40, 12)

mpl.rcParams['figure.facecolor'] = '#00000000'

plt.barh(top.Job_Title,top.Average_yearly_Salary)


plt.title("Top 10 High_Paying Data Analyst Jobs", loc='center')    #'left','right'
plt.xlabel('Average_yearly_Salary')
plt.ylabel('Job_Title')
plt.grid(c='g',ls='--',lw=2.5) #alpha:  adjust the transparency
#plt.xticks(rotation=45);

# %%
# before the plot
sns.set_style('whitegrid')


mpl.rcParams['font.size'] = 25
plt.figure(figsize=(10,10))
#mpl.rcParams['figure.figsize'] = (40, 12)

mpl.rcParams['figure.facecolor'] = '#00000000'

# %%
# before the plot
sns.set_style('whitegrid')


mpl.rcParams['font.size'] = 25
plt.figure(figsize=(10,10))
#mpl.rcParams['figure.figsize'] = (40, 12)

mpl.rcParams['figure.facecolor'] = '#00000000'

# %%
plt.title("Top Paying Data Analyst Jobs", loc='center')    #'left','right'
xlabel('gghghghghg')
plt.ylabel('ghghfghghg')
plt.grid(c='g',ls='--',lw=0.5,alpha=.6) #alpha:  adjust the transparency
plt.xticks(rotation=75);
plt.yticks(rotation=75);
